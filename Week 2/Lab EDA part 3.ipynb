# %% [markdown]
# Activity 3 (Wednesday)
# As a reminder the objective of this study is to predict the total claim amount of a customer and study/investigate the impact of the factors (input features) on the target variable(total claim amount). That means in your exploratory data analysis, you have to look for patterns in this data that show interesting relationships among the input features as well as with relation to the target feature.
#
# Get the numeric data into a dataframe called numerical and categorical columns in a dataframe called categorical. (You can use "np.number" and "object" to select the numerical data types and categorical data types respectively)
# Now we will try to check the normality of the numerical variables visually
# Use the Seaborn library to construct distribution plots for the numerical variables
# Use the Matplotlib library to construct histograms.
# Do the distributions for different numerical variables look like a normal distribution?
# For the numerical variables, check for correlation between the input features. Note: this does not include the target feature (total claim amount).
# Plot the Correlation Heatmap.
# (Optional): Drop one of the two features that show a high correlation between them (greater than 0.9). If there is no pair of features that have a high correlation, then do not drop any features.

# %% [markdown]
# Steps:
# Split to numerical and categorical
# then I focus on the numerical variables

# %%
# import libraries to use (pandas, matplotlib.pyplot and seaborn)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("df4_cleaned.csv")

# %%
data
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 0     LZ68649  Washington             14947.917300       No     Basic
# 1     XL78013      Oregon             22332.439460      Yes  Extended
# 2     HO81102         NaN              4745.181764      NaN     Basic
# 3     HG93801     Arizona              5154.764074       No  Extended
# 4     KR82385  California              5454.587929       No     Basic
# ...       ...         ...                      ...      ...       ...
# 5423  SU71163     Arizona              2771.663013       No     Basic
# 5424  QI63521      Nevada             19228.463620       No     Basic
# 5425  FE99816      Nevada             15563.369440       No   Premium
# 5426  KX53892      Oregon              5259.444853       No     Basic
# 5427  WA60547  California             11971.977650       No   Premium
#
#                  education effective to date employment status gender  income  \
# 0                 Bachelor        2011-02-10          Employed      M   22139
# 1                  College        2011-01-11          Employed      M   49078
# 2     High School or Below        2011-02-14          Employed      M   50549
# 3     High School or Below        2011-01-02          Employed      M   82730
# 4                   Master        2011-01-26          Employed      M   66334
# ...                    ...               ...               ...    ...     ...
# 5423               College        2011-01-07          Employed      M   59855
# 5424  High School or Below        2011-02-24        Unemployed      M       0
# 5425              Bachelor        2011-01-19        Unemployed      F       0
# 5426               College        2011-01-06          Employed      F   61146
# 5427               College        2011-02-13          Employed      F   64195
#
#       ... number of policies     policy type        policy  renew offer type  \
# 0     ...                  2   Personal Auto   Personal L3            Offer3
# 1     ...                  2  Corporate Auto  Corporate L3            Offer2
# 2     ...                  7   Personal Auto   Personal L3            Offer1
# 3     ...                  1  Corporate Auto  Corporate L3            Offer2
# 4     ...                  4   Personal Auto   Personal L3            Offer4
# ...   ...                ...             ...           ...               ...
# 5423  ...                  1   Personal Auto   Personal L2            Offer2
# 5424  ...                  2   Personal Auto   Personal L2            Offer1
# 5425  ...                  7   Personal Auto   Personal L1            Offer3
# 5426  ...                  6   Personal Auto   Personal L3            Offer2
# 5427  ...                  6   Personal Auto   Personal L1            Offer1
#
#       sales channel  total claim amount  vehicle class vehicle size  \
# 0       Call Center          480.000000            SUV      Medsize
# 1            Branch          484.013411  Four-Door Car      Medsize
# 2             Agent          292.800000  Four-Door Car      Medsize
# 3            Branch          442.521087            SUV        Large
# 4       Call Center          331.200000   Two-Door Car      Medsize
# ...             ...                 ...            ...          ...
# 5423         Branch          355.200000   Two-Door Car      Medsize
# 5424         Branch          897.600000     Luxury SUV      Medsize
# 5425            Web         1214.400000     Luxury Car      Medsize
# 5426         Branch          273.018929  Four-Door Car      Medsize
# 5427         Branch          618.288849            SUV      Medsize
#
#      vehicle type month
# 0               A     2
# 1               A     1
# 2               A     2
# 3               A     1
# 4               A     1
# ...           ...   ...
# 5423            A     1
# 5424            A     2
# 5425            A     1
# 5426            A     1
# 5427            A     2
#
# [5428 rows x 26 columns]

# %%
object_data = data.select_dtypes('object')
object_data
# Out:
#      customer       state response  coverage             education  \
# 0     LZ68649  Washington       No     Basic              Bachelor
# 1     XL78013      Oregon      Yes  Extended               College
# 2     HO81102         NaN      NaN     Basic  High School or Below
# 3     HG93801     Arizona       No  Extended  High School or Below
# 4     KR82385  California       No     Basic                Master
# ...       ...         ...      ...       ...                   ...
# 5423  SU71163     Arizona       No     Basic               College
# 5424  QI63521      Nevada       No     Basic  High School or Below
# 5425  FE99816      Nevada       No   Premium              Bachelor
# 5426  KX53892      Oregon       No     Basic               College
# 5427  WA60547  California       No   Premium               College
#
#      effective to date employment status gender location code marital status  \
# 0           2011-02-10          Employed      M      Suburban         Single
# 1           2011-01-11          Employed      M      Suburban         Single
# 2           2011-02-14          Employed      M      Suburban       Divorced
# 3           2011-01-02          Employed      M         Urban        Married
# 4           2011-01-26          Employed      M      Suburban         Single
# ...                ...               ...    ...           ...            ...
# 5423        2011-01-07          Employed      M      Suburban        Married
# 5424        2011-02-24        Unemployed      M      Suburban         Single
# 5425        2011-01-19        Unemployed      F      Suburban        Married
# 5426        2011-01-06          Employed      F         Urban        Married
# 5427        2011-02-13          Employed      F         Urban       Divorced
#
#          policy type        policy renew offer type sales channel  \
# 0      Personal Auto   Personal L3           Offer3   Call Center
# 1     Corporate Auto  Corporate L3           Offer2        Branch
# 2      Personal Auto   Personal L3           Offer1         Agent
# 3     Corporate Auto  Corporate L3           Offer2        Branch
# 4      Personal Auto   Personal L3           Offer4   Call Center
# ...              ...           ...              ...           ...
# 5423   Personal Auto   Personal L2           Offer2        Branch
# 5424   Personal Auto   Personal L2           Offer1        Branch
# 5425   Personal Auto   Personal L1           Offer3           Web
# 5426   Personal Auto   Personal L3           Offer2        Branch
# 5427   Personal Auto   Personal L1           Offer1        Branch
#
#       vehicle class vehicle size vehicle type
# 0               SUV      Medsize            A
# 1     Four-Door Car      Medsize            A
# 2     Four-Door Car      Medsize            A
# 3               SUV        Large            A
# 4      Two-Door Car      Medsize            A
# ...             ...          ...          ...
# 5423   Two-Door Car      Medsize            A
# 5424     Luxury SUV      Medsize            A
# 5425     Luxury Car      Medsize            A
# 5426  Four-Door Car      Medsize            A
# 5427            SUV      Medsize            A
#
# [5428 rows x 17 columns]

# %%
numeric_data = data.select_dtypes('float64')
numeric_data
# Out:
#       customer lifetime value  months since last claim  \
# 0                14947.917300                     34.0
# 1                22332.439460                     10.0
# 2                 4745.181764                      2.0
# 3                 5154.764074                     13.0
# 4                 5454.587929                     25.0
# ...                       ...                      ...
# 5423              2771.663013                     30.0
# 5424             19228.463620                     14.0
# 5425             15563.369440                      NaN
# 5426              5259.444853                      7.0
# 5427             11971.977650                      0.0
#
#       number of open complaints  total claim amount
# 0                           0.0          480.000000
# 1                           0.0          484.013411
# 2                           0.0          292.800000
# 3                           0.0          442.521087
# 4                           0.0          331.200000
# ...                         ...                 ...
# 5423                        4.0          355.200000
# 5424                        0.0          897.600000
# 5425                        NaN         1214.400000
# 5426                        0.0          273.018929
# 5427                        4.0          618.288849
#
# [5428 rows x 4 columns]

# %% [markdown]
# Do the distributions for different numerical variables look like a normal distribution?
# After doing the quick panda histogram, it looks like no.

# %%
numeric_data.hist(figsize=(10,15))
# Out:
# array([[<Axes: title={'center': 'customer lifetime value'}>,
#         <Axes: title={'center': 'months since last claim'}>],
#        [<Axes: title={'center': 'number of open complaints'}>,
#         <Axes: title={'center': 'total claim amount'}>]], dtype=object)

# %% [markdown]
# Correlation between the input factors:
# Open complaints and customer value?

# %%
sns.scatterplot(data=numeric_data, x="number of open complaints", y="customer lifetime value")
# Out:
# <Axes: xlabel='number of open complaints', ylabel='customer lifetime value'>

# %% [markdown]
# Correlation between months since last claim and number of open complaints:

# %%
sns.scatterplot(data=numeric_data, x="months since last claim", y="number of open complaints")
# Out:
# <Axes: xlabel='months since last claim', ylabel='number of open complaints'>

# %%
months since last claim'}>],
       [<Axes: title={'center': 'number of open complaints'

# %% [markdown]
# Correlation Heatmap:

# %%
fig=plt.figure(figsize=(8,5))    #for the heat map we should only put numerical values not categorical
sns.heatmap(numeric_data.corr(),annot=True)
# Out:
# <Axes: >
